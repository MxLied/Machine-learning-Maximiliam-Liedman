# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#loc = mu
#scale = sigma
np.random.seed(42)

x = np.random.normal(loc = 100, scale=100, size=400)

#abs absloute
x = np.abs(x)
#epsilon
eps = np.random.normal(0,50, size=(400))


y = (2*x + 25 + eps)

sns.scatterplot(y=y, x=x)
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(y=x, x=y)
plt.axhline(y= 0,) 
plt.axvline(x=300)

plt.autoscale
# Out:
# <function matplotlib.pyplot.autoscale(enable=True, axis='both', tight=None)>

# %%
np.random.seed(42)

x = np.random.normal(loc = 100, scale=100, size=400)

#abs absloute
x = np.abs(x)
#epsilon
eps = np.random.normal(0,50, size=(400))


y = (2*x + 25 + eps)

# Tar bort punkter över 300, och under 0
mask = (x < 300) & (y > 0)
plt.plot(x, 25 + 2 * x, color='orange', linewidth=3) # regressionslinje med sanna parametrar
x = x[mask]
y = y[mask]

sns.scatterplot(x=x, y=y)
# Out:
# <AxesSubplot: >

# %%
df = pd.DataFrame({'x': x, 'y': y})

df.describe().T
# Out:
#    count        mean         std        min         25%         50%  \
# x  400.0  115.077633   80.175179   0.252936   48.092783  106.804559
# y  400.0  253.238056  164.248516 -54.484387  131.234614  242.927945
#
#           75%          max
# x  163.736140   485.273149
# y  347.790098  1070.348514

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame({'x': x, 'y': y})



df_X = df["x"]
df_y = df["y"]

def train_test_split(X: pd.DataFrame, y: pd.DataFrame, train_fraction: float, random_state: int, replace: bool):
# Out:
#   Cell In[32], line 13
#
#     ^
# IndentationError: expected an indented block
